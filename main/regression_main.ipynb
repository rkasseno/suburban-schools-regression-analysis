# %%
# %run "C:\Users\kassenov_r\suburban-schools-regression-analysis\main\internal_exam_main.ipynb"
# %run "C:\Users\kassenov_r\suburban-schools-regression-analysis\main\monitoring_main.ipynb"
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\kassenov_r\suburban-schools-regression-analysis\myenv\Lib\site-packages\nbformat\reader.py:20, in parse_json(s, **kwargs)
#      19 try:
# ---> 20     nb_dict = json.loads(s, **kwargs)
#      21 except ValueError as e:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1776.0_x64__qbz5n2kfra8p0\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...
