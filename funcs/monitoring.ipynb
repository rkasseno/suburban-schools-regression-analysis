# %%
# %run ".\internal_exam.ipynb"

# %%
df = read_excel_file(r"C:\Users\kassenov_r\OneDrive - AEO NIS\Рабочий стол\Monitoring-SOCH Regression\Monitoring_2023\Monitoring сельские школы (longitudinal data).xlsx")

# %%
schools = [
    'КГУ «Бестамакская средняя школа» Алгинского района Актюбинской области',
    'КГУ «Общеобразовательная школа имени Досова» с. Катарколь Бурабайского района Акмолинской области',
    'КГУ «Общеобразовательная школа № 5 города Ақсай» Бурлинского района ЗКО'
]

# %%
# def sliced + percent multiplied by 100
df = df.loc[df['school_ru'].isin(schools), ['test', 'school_ru', 'fio', 'grade', 'subject', 'percent']].rename(columns={'school_ru' : 'school', 'fio' : 'name'})
df['percent'] = df['percent'] * 100

# %%
df4 = df[df['grade'] == 4]
df8 = df[df['grade'] == 8]

# %%
grouped = df.groupby(['test', 'school', 'name', 'grade', 'subject'])['percent'].mean().reset_index().round(2)
grouped
# Out:
#         test                                             school  \
# 0     RS0423  КГУ «Бестамакская средняя школа» Алгинского ра...
# 1     RS0423  КГУ «Бестамакская средняя школа» Алгинского ра...
# 2     RS0423  КГУ «Бестамакская средняя школа» Алгинского ра...
# 3     RS0423  КГУ «Бестамакская средняя школа» Алгинского ра...
# 4     RS0423  КГУ «Бестамакская средняя школа» Алгинского ра...
# ...      ...                                                ...
# 3330  RS1122  КГУ «Общеобразовательная школа № 5 города Ақса...
# 3331  RS1122  КГУ «Общеобразовательная школа № 5 города Ақса...
# 3332  RS1122  КГУ «Общеобразовательная школа № 5 города Ақса...
# 3333  RS1122  КГУ «Общеобразовательная школа № 5 города Ақса...
# 3334  RS1122  КГУ «Общеобразовательная школа № 5 города Ақса...
#
#                            name  grade subject  percent
# 0     Абдрахман Абылай Асқарұлы      8   8BIOL     70.0
# 1     Абдрахман Абылай Асқарұлы      8   8CHEM     75.0
# 2     Абдрахман Абылай Асқарұлы      8   8ENFL     40.0
# 3     Абдрахман Абылай Асқарұлы      8   8KZFL     85.0
# 4     Абдрахман Абылай Асқарұлы      8   8MATH     75.0
# ...                         ...    ...     ...      ...
# 3330      Ғизат Бағдат Жеңісұлы      4   4KZFL     10.0
# 3331      Ғизат Бағдат Жеңісұлы      4   4MATH     50.0
# 3332      Ғизат Бағдат Жеңісұлы      4   4SCIE     30.0
# 3333           Қуанышқызы Ғалия      4   4KZFL     15.0
# 3334           Қуанышқызы Ғалия      4   4SCIE     40.0
#
# [3335 rows x 6 columns]

# %%
west = df[(df['school'] == 'КГУ «Общеобразовательная школа № 5 города Ақсай» Бурлинского района ЗКО') & (df['test'] == 'RS0423')]
west
# Out:
#          test                                             school  \
# 7      RS0423  КГУ «Общеобразовательная школа № 5 города Ақса...
# 8      RS0423  КГУ «Общеобразовательная школа № 5 города Ақса...
# 11     RS0423  КГУ «Общеобразовательная школа № 5 города Ақса...
# 17     RS0423  КГУ «Общеобразовательная школа № 5 города Ақса...
# 22     RS0423  КГУ «Общеобразовательная школа № 5 города Ақса...
# ...       ...                                                ...
# 26482  RS0423  КГУ «Общеобразовательная школа № 5 города Ақса...
# 26495  RS0423  КГУ «Общеобразовательная школа № 5 города Ақса...
# 26624  RS0423  КГУ «Общеобразовательная школа № 5 города Ақса...
# 26631  RS0423  КГУ «Общеобразовательная школа № 5 города Ақса...
# 26652  RS0423  КГУ «Общеобразовательная школа № 5 города Ақса...
#
#                                     name  grade subject  percent
# 7                Ваймер Роман Витальевич      8   8KZSL     25.0
# 8      Чермошенцева Ксения Александровна      8   8KZSL     75.0
# 11               Мұрат Суляйман Арманұлы      8   8KZSL     75.0
# 17           Макатова Татьяна Витальевна      8   8KZSL     75.0
# 22       Мансуров Абибулла Александрович      8   8KZSL     30.0
# ...                                  ...    ...     ...      ...
# 26482        Избасарова Айлита Рашитовна      8   8RUFL     55.0
# 26495           Махлеев Дмитрий Павлович      8   8RUFL     45.0
# 26624             Нұрман Әмина Мұханқызы      8   8PHYS     35.0
# 26631          Жумашева Сымбат Ерболовна      8   8ENFL     50.0
# 26652        Акбасов Даниал Сагинжанович      4   4MATH     80.0
#
# [632 rows x 6 columns]
